# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Computação em Nuvem I
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Amazon Web Services;</li>
#   <li>AWS IAM;</li>
#   <li>AWS S3;</li>
#   <li>AWS Athena.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Amazon Web Services

# %% [markdown]
#  1. Crie uma conta na [AWS](https://portal.aws.amazon.com/);
#  1. Acesse a sua conta e selecione a região mais próxima da sua residência.

# %% [markdown]
# ## 2\. AWS S3

# %% [markdown]
# Replique as atividades do item 3.3 em sua conta.

# %%
import pandas as pd
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# **Criei o bucket e carreguei o CSV**

# %% [markdown]
# ![Imagem do WhatsApp de 2024-06-29 à(s) 18.53.56_969c1aa3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 3\. AWS Athena

# %% [markdown]
# Replique as atividades do item 4.3 em sua conta.

# %% [markdown]
# **No S3 criei um bucket para salvar as querys e coloquei como padrão**

# %% [markdown]
# ![Imagem do WhatsApp de 2024-06-29 à(s) 18.54.57_062199ee.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Realizei algumas consultas.**
#
#
# ```sql
# SELECT * FROM iris LIMIT 10;
# ```

# %% [markdown]
# ![Imagem do WhatsApp de 2024-06-29 à(s) 18.57.00_636b9dd4.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Esta consulta mostra a media das pentalas.**
#
# ```sql
# SELECT
#     specie,
#     round(avg(sepal_length), 4) as avg_sepal_length,
#     round(avg(sepal_width),  4) as avg_sepal_width,
#     round(avg(petal_length), 4) as avg_petal_length,
#     round(avg(petal_width),  4) as avg_petal_width
# FROM iris
# GROUP BY specie;
# ```

# %% [markdown]
# ![Imagem do WhatsApp de 2024-06-29 à(s) 18.57.25_23fa4f4f.jpg](data:image/jpeg;base64,...)
